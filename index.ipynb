# %% [markdown]
# Tutorials and Ideas in Julia
# ===
#
# I started learning Julia during the last week of July (2015). I like it. I'll be writing some ideas about and tutorials on Julia, here.
#
# - [`@async` is your friend](./async_is_your_friend.html)
